# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
for columns in df:
    sns.boxplot(x=df[columns])
    plt.show()

# %%
for columns in df:
    sns.histplot(x=df[columns])
    plt.show()

# %% [markdown]
# variables dont show normal distribution - will try log transformation to help reduce skewdness of data

# %%
df_log = pd.DataFrame([])
for column in df:
    df_log['log' + column] = np.log(df[column])
# Out:
# /Users/katarinasalcedo/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_log
# Out:
#       logfixed_acidity  logvolatile_acidity  logcitric_acid  \
# 0             2.001480            -0.356675            -inf
# 1             2.054124            -0.127833            -inf
# 2             2.054124            -0.274437       -3.218876
# 3             2.415914            -1.272966       -0.579818
# 4             2.001480            -0.356675            -inf
# ...                ...                  ...             ...
# 1594          1.824549            -0.510826       -2.525729
# 1595          1.774952            -0.597837       -2.302585
# 1596          1.840550            -0.673345       -2.040221
# 1597          1.774952            -0.438505       -2.120264
# 1598          1.791759            -1.171183       -0.755023
#
#       logresidual_sugar  logchlorides  logfree_sulfur_dioxide  \
# 0              0.641854     -2.577022                2.397895
# 1              0.955511     -2.322788                3.218876
# ...

# %%
df_log.drop(columns=['logcitric_acid'],inplace=True)
df_log
# Out:
#       logfixed_acidity  logvolatile_acidity  logresidual_sugar  logchlorides  \
# 0             2.001480            -0.356675           0.641854     -2.577022
# 1             2.054124            -0.127833           0.955511     -2.322788
# 2             2.054124            -0.274437           0.832909     -2.385967
# 3             2.415914            -1.272966           0.641854     -2.590267
# 4             2.001480            -0.356675           0.641854     -2.577022
# ...                ...                  ...                ...           ...
# 1594          1.824549            -0.510826           0.693147     -2.407946
# 1595          1.774952            -0.597837           0.788457     -2.780621
# 1596          1.840550            -0.673345           0.832909     -2.577022
# 1597          1.774952            -0.438505           0.693147     -2.590267
# 1598          1.791759            -1.171183           1.280934     -2.703063
#
# ...

# %%
for column in df_log:
    sns.histplot(x=df_log[column])
    plt.show()

# %% [markdown]
# lots of outliers in data (fixed acidity, residual sugar, sulphates, pH, density, chlorides, total sulfur dioxide, free sulfur dioxide, volatile acidity. variables with few outliers - easier to drop them. variables with lots of outliers drop or change to mean/median?

# %%
# for column in df:
#     sns.violinplot(x=df[column],y=df['quality'],label = column)
#     plt.legend()
#     plt.show()

# %%
fig = plt.figure(figsize=(12,10))
sns.violinplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats

# %%
f = 'quality~'+ '+'.join(df.columns[:-1])

# %%
model = ols(formula = f, data= df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.361
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     81.35
# Date:                Tue, 06 Jul 2021   Prob (F-statistic):          1.79e-145
# Time:                        01:12:16   Log-Likelihood:                -1569.1
# No. Observations:                1599   AIC:                             3162.
# Df Residuals:                    1587   BIC:                             3227.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
f = 'logquality~'+ '+'.join(df_log.columns[:-1])
model = ols(formula = f, data= df_log).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             logquality   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     81.57
# Date:                Tue, 06 Jul 2021   Prob (F-statistic):          2.56e-135
# Time:                        01:12:24   Log-Likelihood:                 1144.7
# No. Observations:                1599   AIC:                            -2267.
# Df Residuals:                    1588   BIC:                            -2208.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# r2 went from .361 to .339 after log transformation - maybe dont take log of quality? - skewness and kurtosis also increased after log transformation. think we have to remove outliers before/after transformation?

# %%
for column in df:
    fig = plt.figure(figsize=(15,8))
    fig = sm.graphics.plot_regress_exog(model,column, fig=fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-70d163222ac8> in <module>
#       1 for column in df:
#       2     fig = plt.figure(figsize=(15,8))
# ----> 3     fig = sm.graphics.plot_regress_exog(model,column, fig=fig)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/graphics/regressionplots.py in plot_regress_exog(results, exog_idx, fig)
#     218     fig = utils.create_mpl_fig(fig)
#     219
# --> 220     exog_name, exog_idx = utils.maybe_name_or_idx(exog_idx, results.model)
#     221     results = maybe_unwrap_results(results)
#     222
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/graphics/utils.py in maybe_name_or_idx(idx, model)
#     110     else: # assume we've got a string variable
#     111         exog_name = idx
# --> 112         exog_idx = model.exog_names.index(idx)
#     113
# ...

# %% [markdown]
# Homoscedasticity assumption:
# volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, sulphates do not meet assumption - show strong heteroscedasticity -
# *outliers can cause heteroscedasticity*

# %% [markdown]
# ## Checking for multicollinearity

# %%
data_pre = df.iloc[:,:-1]
data_pre
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
matrix = pd.plotting.scatter_matrix(data_pre, figsize=[10,10]);


[s.xaxis.label.set_rotation(90) for s in matrix.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in matrix.reshape(-1)]


[s.get_yaxis().set_label_coords(-1,0.5) for s in matrix.reshape(-1)]

[s.set_xticks(()) for s in matrix.reshape(-1)]
[s.set_yticks(()) for s in matrix.reshape(-1)]

plt.show()

# %%
abs(data_pre.corr()) > .75
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity                  True             False        False
# volatile_acidity              False              True        False
# citric_acid                   False             False         True
# residual_sugar                False             False        False
# chlorides                     False             False        False
# free_sulfur_dioxide           False             False        False
# total_sulfur_dioxide          False             False        False
# density                       False             False        False
# pH                            False             False        False
# sulphates                     False             False        False
# alcohol                       False             False        False
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity                  False      False                False
# ...

# %%
df_ = data_pre.corr().abs().stack().reset_index().sort_values(0,ascending=False)
df_['pairs'] = list(zip(df_.level_0, df_.level_1))
df_.set_index(['pairs'], inplace=True)
df_.drop(columns=['level_1','level_0'],inplace=True)
df_.columns = ['cc']
df_.drop_duplicates(inplace=True)
df_
# Out:
#                                                    cc
# pairs
# (fixed_acidity, fixed_acidity)               1.000000
# (pH, fixed_acidity)                          0.682978
# (fixed_acidity, citric_acid)                 0.671703
# (density, fixed_acidity)                     0.668047
# (total_sulfur_dioxide, free_sulfur_dioxide)  0.667666
# (citric_acid, volatile_acidity)              0.552496
# (pH, citric_acid)                            0.541904
# (density, alcohol)                           0.496180
# (sulphates, chlorides)                       0.371260
# (density, citric_acid)                       0.364947
# (residual_sugar, density)                    0.355283
# (density, pH)                                0.341699
# (citric_acid, sulphates)                     0.312770
# (pH, chlorides)                              0.265026
# (sulphates, volatile_acidity)                0.260987
# (fixed_acidity, volatile_acidity)            0.256131
# ...

# %% [markdown]
# no high correlation between variables

# %%
white = pd.read_csv('wines/WineQuality-WhiteWine.csv')
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
for column in white:
    sns.boxplot(x=white[column])
    plt.show()

# %%
white['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])
